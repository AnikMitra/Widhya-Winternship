# %%
import pandas as pd
import matplotlib as mt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv")

# %%
df
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
df1 = df[["Date","ConfirmedIndianNational","ConfirmedForeignNational","Cured","Deaths"]]

# %%
df1
# Out:
#          Date  ConfirmedIndianNational  ConfirmedForeignNational  Cured  \
# 0    30/01/20                        1                         0      0
# 1    31/01/20                        1                         0      0
# 2    01/02/20                        2                         0      0
# 3    02/02/20                        3                         0      0
# 4    03/02/20                        3                         0      0
# ..        ...                      ...                       ...    ...
# 265  21/03/20                        4                         0      0
# 266  21/03/20                       13                         0      0
# 267  21/03/20                       23                         1      9
# 268  21/03/20                        3                         0      0
# 269  21/03/20                        3                         0      0
#
#      Deaths
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# ...

# %%
df2 = df1.groupby(by="Date", sort = False)

# %%
df3 = df2[["Date","ConfirmedIndianNational","ConfirmedForeignNational","Cured", "Deaths"]].sum()

# %%
df3["Totalcases"] = df3.sum(axis=1)

# %%
df3
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df3["Totalcases"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df3[["Cured", "Deaths"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df3["Increaseincases"] = df3["Totalcases"].diff()

# %%
df3
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df3["Rateofincrease"] = df3["Increaseincases"] / df3["Totalcases"]

# %%
df3
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
df4 = df3.iloc[-18:,]

# %%
df4
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 04/03/20                       12                        16      3       0
# 05/03/20                       14                        16      3       0
# 06/03/20                       15                        16      3       0
# 07/03/20                       18                        16      3       0
# 08/03/20                       23                        16      3       0
# 09/03/20                       30                        16      3       0
# 10/03/20                       42                        16      3       0
# 11/03/20                       44                        16      3       0
# 12/03/20                       57                        17      3       0
# 13/03/20                       64                        17      3       1
# 14/03/20                       67                        17     10       2
# ...

# %%
r = sum(df4["Rateofincrease"])/18

# %%
import math

# %%
P_t = df4.iloc[0,5] * math.exp(r * 26)

# %%
P_t
# Out:
# 1298.3606128327142
